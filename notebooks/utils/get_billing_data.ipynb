# %%
import os
import glob

# %%
os.getcwd()
# Out:
# '/Users/egeriicw/Personal-Projects/energy_data_analysis/notebooks/utils'

# %%
data_dir = '../../data/billing/DataImportEDI/'

# %%
glob.glob(data_dir + '**/VAP*.txt', recursive=True)
# Out:
# ['../../data/billing/DataImportEDI/20111012043820/VAP9423383257-00522737-20111012.txt',
#  '../../data/billing/DataImportEDI/20111012043820/VAP4032400121-00522781-20111012.txt',
#  '../../data/billing/DataImportEDI/20111012043820/VAP3103257501-00522763-20111012.txt',
#  '../../data/billing/DataImportEDI/20111012043820/VAP8955365005-00522755-20111012.txt',
#  '../../data/billing/DataImportEDI/20111012043820/VAP9006000005-00522786-20111012.txt',
#  '../../data/billing/DataImportEDI/20111012043820/VAP0851910000-00522719-20111012.txt',
#  '../../data/billing/DataImportEDI/20111012043820/VAP0045282506-00522788-20111012.txt',
#  '../../data/billing/DataImportEDI/20111012043820/VAP5746157501-00522729-20111012.txt',
#  '../../data/billing/DataImportEDI/20111012043820/VAP2225822507-00522761-20111012.txt',
#  '../../data/billing/DataImportEDI/20111012043820/VAP6070697393-00522765-20111012.txt',
#  '../../data/billing/DataImportEDI/20111012043820/VAP3004480236-00522804-20111012.txt',
# ...
